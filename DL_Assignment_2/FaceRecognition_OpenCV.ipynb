# %%
# !pip install opencv-python tensorflow
# Out:
# Requirement already satisfied: opencv-python in c:\users\odshi\appdata\local\programs\python\python311\lib\site-packages (4.12.0.88)
# Requirement already satisfied: tensorflow in c:\users\odshi\appdata\local\programs\python\python311\lib\site-packages (2.19.0)
# Requirement already satisfied: numpy<2.3.0,>=2 in c:\users\odshi\appdata\local\programs\python\python311\lib\site-packages (from opencv-python) (2.2.6)
# Requirement already satisfied: absl-py>=1.0.0 in c:\users\odshi\appdata\local\programs\python\python311\lib\site-packages (from tensorflow) (2.3.0)
# Requirement already satisfied: astunparse>=1.6.0 in c:\users\odshi\appdata\local\programs\python\python311\lib\site-packages (from tensorflow) (1.6.3)
# Requirement already satisfied: flatbuffers>=24.3.25 in c:\users\odshi\appdata\local\programs\python\python311\lib\site-packages (from tensorflow) (25.2.10)
# Requirement already satisfied: gast!=0.5.0,!=0.5.1,!=0.5.2,>=0.2.1 in c:\users\odshi\appdata\local\programs\python\python311\lib\site-packages (from tensorflow) (0.6.0)
# Requirement already satisfied: google-pasta>=0.1.1 in c:\users\odshi\appdata\local\programs\python\python311\lib\site-packages (from tensorflow) (0.2.0)
# Requirement already satisfied: libclang>=13.0.0 in c:\users\odshi\appdata\local\programs\python\python311\lib\site-packages (from tensorflow) (18.1.1)
# Requirement already satisfied: opt-einsum>=2.3.2 in c:\users\odshi\appdata\local\programs\python\python311\lib\site-packages (from tensorflow) (3.4.0)
# Requirement already satisfied: packaging in c:\users\odshi\appdata\local\programs\python\python311\lib\site-packages (from tensorflow) (24.2)
# Requirement already satisfied: protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<6.0.0dev,>=3.20.3 in c:\users\odshi\appdata\local\programs\python\python311\lib\site-packages (from tensorflow) (4.25.8)
# Requirement already satisfied: requests<3,>=2.21.0 in c:\users\odshi\appdata\local\programs\python\python311\lib\site-packages (from tensorflow) (2.32.4)
# Requirement already satisfied: setuptools in c:\users\odshi\appdata\local\programs\python\python311\lib\site-packages (from tensorflow) (65.5.0)
# Requirement already satisfied: six>=1.12.0 in c:\users\odshi\appdata\local\programs\python\python311\lib\site-packages (from tensorflow) (1.17.0)
# Requirement already satisfied: termcolor>=1.1.0 in c:\users\odshi\appdata\local\programs\python\python311\lib\site-packages (from tensorflow) (3.1.0)
# Requirement already satisfied: typing-extensions>=3.6.6 in c:\users\odshi\appdata\local\programs\python\python311\lib\site-packages (from tensorflow) (4.14.0)
# Requirement already satisfied: wrapt>=1.11.0 in c:\users\odshi\appdata\local\programs\python\python311\lib\site-packages (from tensorflow) (1.17.2)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in c:\users\odshi\appdata\local\programs\python\python311\lib\site-packages (from tensorflow) (1.73.0)
# Requirement already satisfied: tensorboard~=2.19.0 in c:\users\odshi\appdata\local\programs\python\python311\lib\site-packages (from tensorflow) (2.19.0)
# Requirement already satisfied: keras>=3.5.0 in c:\users\odshi\appdata\local\programs\python\python311\lib\site-packages (from tensorflow) (3.10.0)
# Collecting numpy<2.3.0,>=2 (from opencv-python)
#   Downloading numpy-2.1.3-cp311-cp311-win_amd64.whl.metadata (60 kB)
# Requirement already satisfied: h5py>=3.11.0 in c:\users\odshi\appdata\local\programs\python\python311\lib\site-packages (from tensorflow) (3.14.0)
# Requirement already satisfied: ml-dtypes<1.0.0,>=0.5.1 in c:\users\odshi\appdata\local\programs\python\python311\lib\site-packages (from tensorflow) (0.5.1)
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.23.1 in c:\users\odshi\appdata\local\programs\python\python311\lib\site-packages (from tensorflow) (0.31.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\users\odshi\appdata\local\programs\python\python311\lib\site-packages (from requests<3,>=2.21.0->tensorflow) (3.4.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\odshi\appdata\local\programs\python\python311\lib\site-packages (from requests<3,>=2.21.0->tensorflow) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\odshi\appdata\local\programs\python\python311\lib\site-packages (from requests<3,>=2.21.0->tensorflow) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\odshi\appdata\local\programs\python\python311\lib\site-packages (from requests<3,>=2.21.0->tensorflow) (2025.6.15)
# Requirement already satisfied: markdown>=2.6.8 in c:\users\odshi\appdata\local\programs\python\python311\lib\site-packages (from tensorboard~=2.19.0->tensorflow) (3.8)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in c:\users\odshi\appdata\local\programs\python\python311\lib\site-packages (from tensorboard~=2.19.0->tensorflow) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in c:\users\odshi\appdata\local\programs\python\python311\lib\site-packages (from tensorboard~=2.19.0->tensorflow) (3.1.3)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in c:\users\odshi\appdata\local\programs\python\python311\lib\site-packages (from astunparse>=1.6.0->tensorflow) (0.45.1)
# Requirement already satisfied: rich in c:\users\odshi\appdata\local\programs\python\python311\lib\site-packages (from keras>=3.5.0->tensorflow) (14.0.0)
# Requirement already satisfied: namex in c:\users\odshi\appdata\local\programs\python\python311\lib\site-packages (from keras>=3.5.0->tensorflow) (0.1.0)
# Requirement already satisfied: optree in c:\users\odshi\appdata\local\programs\python\python311\lib\site-packages (from keras>=3.5.0->tensorflow) (0.16.0)
# Requirement already satisfied: MarkupSafe>=2.1.1 in c:\users\odshi\appdata\local\programs\python\python311\lib\site-packages (from werkzeug>=1.0.1->tensorboard~=2.19.0->tensorflow) (3.0.2)
# Requirement already satisfied: markdown-it-py>=2.2.0 in c:\users\odshi\appdata\local\programs\python\python311\lib\site-packages (from rich->keras>=3.5.0->tensorflow) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in c:\users\odshi\appdata\local\programs\python\python311\lib\site-packages (from rich->keras>=3.5.0->tensorflow) (2.19.1)
# Requirement already satisfied: mdurl~=0.1 in c:\users\odshi\appdata\local\programs\python\python311\lib\site-packages (from markdown-it-py>=2.2.0->rich->keras>=3.5.0->tensorflow) (0.1.2)
# Downloading numpy-2.1.3-cp311-cp311-win_amd64.whl (12.9 MB)
#    ---------------------------------------- 0.0/12.9 MB ? eta -:--:--
#    ---------------------------------------- 0.0/12.9 MB ? eta -:--:--
#     --------------------------------------- 0.3/12.9 MB ? eta -:--:--
#    - -------------------------------------- 0.5/12.9 MB 4.2 MB/s eta 0:00:03
#    -- ------------------------------------- 0.8/12.9 MB 1.2 MB/s eta 0:00:11
#    ---- ----------------------------------- 1.3/12.9 MB 1.8 MB/s eta 0:00:07
#    ---- ----------------------------------- 1.6/12.9 MB 1.6 MB/s eta 0:00:08
#    ----- ---------------------------------- 1.8/12.9 MB 1.5 MB/s eta 0:00:08
#    ----- ---------------------------------- 1.8/12.9 MB 1.5 MB/s eta 0:00:08
#    ----- ---------------------------------- 1.8/12.9 MB 1.5 MB/s eta 0:00:08
#    ------ --------------------------------- 2.1/12.9 MB 1.1 MB/s eta 0:00:10
#    ------ --------------------------------- 2.1/12.9 MB 1.1 MB/s eta 0:00:10
#    ------ --------------------------------- 2.1/12.9 MB 1.1 MB/s eta 0:00:10
#    ------- -------------------------------- 2.4/12.9 MB 952.0 kB/s eta 0:00:12
#    ------- -------------------------------- 2.4/12.9 MB 952.0 kB/s eta 0:00:12
#    -------- ------------------------------- 2.6/12.9 MB 867.7 kB/s eta 0:00:12
#    -------- ------------------------------- 2.9/12.9 MB 897.1 kB/s eta 0:00:12
#    -------- ------------------------------- 2.9/12.9 MB 897.1 kB/s eta 0:00:12
#    --------- ------------------------------ 3.1/12.9 MB 854.4 kB/s eta 0:00:12
#    --------- ------------------------------ 3.1/12.9 MB 854.4 kB/s eta 0:00:12
#    --------- ------------------------------ 3.1/12.9 MB 854.4 kB/s eta 0:00:12
#    ---------- ----------------------------- 3.4/12.9 MB 792.6 kB/s eta 0:00:12
#    ---------- ----------------------------- 3.4/12.9 MB 792.6 kB/s eta 0:00:12
#    ----------- ---------------------------- 3.7/12.9 MB 787.4 kB/s eta 0:00:12
#    ------------ --------------------------- 3.9/12.9 MB 812.7 kB/s eta 0:00:11
#    ------------ --------------------------- 3.9/12.9 MB 812.7 kB/s eta 0:00:11
#    ------------ --------------------------- 3.9/12.9 MB 812.7 kB/s eta 0:00:11
#    ------------- -------------------------- 4.5/12.9 MB 803.7 kB/s eta 0:00:11
#    -------------- ------------------------- 4.7/12.9 MB 831.4 kB/s eta 0:00:10
#    --------------- ------------------------ 5.0/12.9 MB 853.0 kB/s eta 0:00:10
#    ----------------- ---------------------- 5.8/12.9 MB 931.9 kB/s eta 0:00:08
#    ----------------- ---------------------- 5.8/12.9 MB 931.9 kB/s eta 0:00:08
#    ------------------ --------------------- 6.0/12.9 MB 943.9 kB/s eta 0:00:08
#    --------------------- ------------------ 6.8/12.9 MB 1.0 MB/s eta 0:00:06
#    ----------------------- ---------------- 7.6/12.9 MB 1.1 MB/s eta 0:00:05
#    ----------------------------- ---------- 9.4/12.9 MB 1.3 MB/s eta 0:00:03
#    ------------------------------- -------- 10.2/12.9 MB 1.4 MB/s eta 0:00:02
#    ------------------------------------- -- 12.1/12.9 MB 1.6 MB/s eta 0:00:01
#    ---------------------------------------- 12.9/12.9 MB 1.7 MB/s  0:00:07
# Installing collected packages: numpy
#   Attempting uninstall: numpy
#     Found existing installation: numpy 2.2.6
#     Uninstalling numpy-2.2.6:
#       Successfully uninstalled numpy-2.2.6
# Successfully installed numpy-2.1.3
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# tensorflow-intel 2.16.1 requires ml-dtypes~=0.3.1, but you have ml-dtypes 0.5.1 which is incompatible.
# tensorflow-intel 2.16.1 requires numpy<2.0.0,>=1.23.5; python_version <= "3.11", but you have numpy 2.1.3 which is incompatible.
# tensorflow-intel 2.16.1 requires tensorboard<2.17,>=2.16, but you have tensorboard 2.19.0 which is incompatible.

# %%
import cv2
from ultralytics import YOLO
import datetime
import os

# Create folder for saved detections
save_dir = "detections"
os.makedirs(save_dir, exist_ok=True)

# Load YOLOv8 model
model = YOLO("yolov8s.pt")  # Change to yolov8n.pt, yolov8m.pt, etc.

# Open webcam
cap = cv2.VideoCapture(0)
if not cap.isOpened():
    print("Error: Could not open webcam.")
    exit()

frame_count = 0

while True:
    ret, frame = cap.read()
    if not ret:
        break

    # YOLO object detection
    results = model.track(frame, stream=True)
    counts = {}

    for result in results:
        class_names = result.names

        for box in result.boxes:
            if box.conf[0] > 0.4:  # Confidence threshold
                x1, y1, x2, y2 = map(int, box.xyxy[0])
                cls = int(box.cls[0])
                class_name = class_names[cls]

                counts[class_name] = counts.get(class_name, 0) + 1

                # Draw bounding box and label
                cv2.rectangle(frame, (x1, y1), (x2, y2), (0, 255, 0), 2)
                cv2.putText(frame, f"{class_name} {box.conf[0]:.2f}",
                            (x1, y1 - 10), cv2.FONT_HERSHEY_SIMPLEX,
                            0.9, (0, 255, 0), 2)

    # Show object counts in frame
    y_offset = 30
    for cls_name, count in counts.items():
        cv2.putText(frame, f"{cls_name}: {count}", (10, y_offset),
                    cv2.FONT_HERSHEY_SIMPLEX, 0.9, (0, 255, 255), 2)
        y_offset += 30

    # Save detected frame every 5 detections
    if counts:
        frame_count += 1
        if frame_count % 5 == 0:
            filename = os.path.join(save_dir, f"detection_{datetime.datetime.now().strftime('%Y%m%d_%H%M%S')}.jpg")
            cv2.imwrite(filename, frame)
            print(f"Saved: {filename}")

    # Show the live video feed
    cv2.imshow("YOLOv8 Object Detection", frame)

    # Exit when 'q' is pressed
    if cv2.waitKey(1) & 0xFF == ord('q'):
        break

# Release webcam & close window
cap.release()
cv2.destroyAllWindows()
# Out:
# 0: 480x640 6 persons, 5 chairs, 230.7ms
# Speed: 2.8ms preprocess, 230.7ms inference, 1.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 8 persons, 5 chairs, 185.9ms
# Speed: 2.1ms preprocess, 185.9ms inference, 1.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 9 persons, 5 chairs, 199.5ms
# Speed: 1.8ms preprocess, 199.5ms inference, 1.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 7 persons, 5 chairs, 1 laptop, 230.1ms
# Speed: 1.9ms preprocess, 230.1ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 7 persons, 5 chairs, 1 laptop, 223.1ms
# Speed: 2.0ms preprocess, 223.1ms inference, 1.1ms postprocess per image at shape (1, 3, 480, 640)
# Saved: detections\detection_20250812_114257.jpg
#
# 0: 480x640 8 persons, 5 chairs, 1 tv, 1 laptop, 237.8ms
# Speed: 3.9ms preprocess, 237.8ms inference, 1.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 8 persons, 5 chairs, 1 tv, 233.4ms
# Speed: 2.7ms preprocess, 233.4ms inference, 1.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 7 persons, 5 chairs, 195.4ms
# Speed: 2.1ms preprocess, 195.4ms inference, 1.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 8 persons, 5 chairs, 1 tv, 223.0ms
# Speed: 1.6ms preprocess, 223.0ms inference, 1.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 7 persons, 5 chairs, 182.7ms
# Speed: 1.9ms preprocess, 182.7ms inference, 1.3ms postprocess per image at shape (1, 3, 480, 640)
# Saved: detections\detection_20250812_114258.jpg
#
# 0: 480x640 8 persons, 1 donut, 5 chairs, 1 tv, 212.3ms
# Speed: 2.4ms preprocess, 212.3ms inference, 1.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 7 persons, 5 chairs, 176.1ms
# Speed: 2.1ms preprocess, 176.1ms inference, 1.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 7 persons, 5 chairs, 202.5ms
# Speed: 1.2ms preprocess, 202.5ms inference, 1.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 6 persons, 5 chairs, 235.2ms
# Speed: 1.5ms preprocess, 235.2ms inference, 1.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 7 persons, 5 chairs, 211.9ms
# Speed: 1.2ms preprocess, 211.9ms inference, 1.2ms postprocess per image at shape (1, 3, 480, 640)
# Saved: detections\detection_20250812_114300.jpg
#
# 0: 480x640 7 persons, 5 chairs, 216.7ms
# Speed: 1.8ms preprocess, 216.7ms inference, 2.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 8 persons, 5 chairs, 232.9ms
# Speed: 3.1ms preprocess, 232.9ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 8 persons, 5 chairs, 218.7ms
# Speed: 2.2ms preprocess, 218.7ms inference, 1.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 8 persons, 5 chairs, 222.7ms
# Speed: 1.2ms preprocess, 222.7ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 8 persons, 1 donut, 5 chairs, 188.7ms
# Speed: 1.7ms preprocess, 188.7ms inference, 1.5ms postprocess per image at shape (1, 3, 480, 640)
# Saved: detections\detection_20250812_114301.jpg
#
# 0: 480x640 8 persons, 1 donut, 5 chairs, 1 laptop, 182.8ms
# Speed: 2.7ms preprocess, 182.8ms inference, 1.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 8 persons, 5 chairs, 236.2ms
# Speed: 2.4ms preprocess, 236.2ms inference, 1.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 8 persons, 5 chairs, 239.0ms
# Speed: 2.9ms preprocess, 239.0ms inference, 1.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 9 persons, 5 chairs, 1 laptop, 237.9ms
# Speed: 2.0ms preprocess, 237.9ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 8 persons, 1 donut, 5 chairs, 221.1ms
# Speed: 1.7ms preprocess, 221.1ms inference, 1.1ms postprocess per image at shape (1, 3, 480, 640)
# Saved: detections\detection_20250812_114302.jpg
#
# 0: 480x640 8 persons, 4 chairs, 244.0ms
# Speed: 2.7ms preprocess, 244.0ms inference, 1.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 8 persons, 6 chairs, 233.0ms
# Speed: 2.2ms preprocess, 233.0ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 9 persons, 6 chairs, 217.8ms
# Speed: 1.9ms preprocess, 217.8ms inference, 1.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 9 persons, 6 chairs, 1 laptop, 222.8ms
# Speed: 3.1ms preprocess, 222.8ms inference, 1.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 9 persons, 6 chairs, 1 laptop, 217.7ms
# Speed: 2.9ms preprocess, 217.7ms inference, 1.1ms postprocess per image at shape (1, 3, 480, 640)
# Saved: detections\detection_20250812_114303.jpg
#
# 0: 480x640 9 persons, 6 chairs, 218.6ms
# Speed: 1.9ms preprocess, 218.6ms inference, 1.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 9 persons, 6 chairs, 221.0ms
# Speed: 2.5ms preprocess, 221.0ms inference, 1.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 9 persons, 6 chairs, 213.0ms
# Speed: 2.7ms preprocess, 213.0ms inference, 1.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 9 persons, 6 chairs, 202.4ms
# Speed: 1.5ms preprocess, 202.4ms inference, 1.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 9 persons, 6 chairs, 153.5ms
# Speed: 1.4ms preprocess, 153.5ms inference, 2.1ms postprocess per image at shape (1, 3, 480, 640)
# Saved: detections\detection_20250812_114305.jpg
#
# 0: 480x640 9 persons, 6 chairs, 230.7ms
# Speed: 2.1ms preprocess, 230.7ms inference, 1.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 9 persons, 6 chairs, 216.5ms
# Speed: 1.6ms preprocess, 216.5ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 9 persons, 6 chairs, 229.4ms
# Speed: 3.3ms preprocess, 229.4ms inference, 1.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 8 persons, 5 chairs, 175.3ms
# Speed: 1.8ms preprocess, 175.3ms inference, 2.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 9 persons, 5 chairs, 1 laptop, 212.3ms
# Speed: 1.7ms preprocess, 212.3ms inference, 1.2ms postprocess per image at shape (1, 3, 480, 640)
# Saved: detections\detection_20250812_114306.jpg
#
# 0: 480x640 8 persons, 5 chairs, 209.7ms
# Speed: 1.8ms preprocess, 209.7ms inference, 1.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 9 persons, 5 chairs, 213.4ms
# Speed: 1.8ms preprocess, 213.4ms inference, 1.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 9 persons, 5 chairs, 242.6ms
# Speed: 3.9ms preprocess, 242.6ms inference, 1.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 9 persons, 6 chairs, 238.5ms
# Speed: 3.7ms preprocess, 238.5ms inference, 1.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 8 persons, 5 chairs, 218.4ms
# Speed: 1.9ms preprocess, 218.4ms inference, 1.4ms postprocess per image at shape (1, 3, 480, 640)
# Saved: detections\detection_20250812_114307.jpg
#
# 0: 480x640 9 persons, 6 chairs, 243.9ms
# Speed: 2.6ms preprocess, 243.9ms inference, 1.6ms postprocess per image at shape (1, 3, 480, 640)
